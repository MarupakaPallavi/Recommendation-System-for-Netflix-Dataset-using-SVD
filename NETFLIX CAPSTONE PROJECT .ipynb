# %% [markdown]
# # Problem statement

# %% [markdown]
# ## Customer Behaviour and it’s prediction lies at the core of every Business Model. From Stock Exchange, e Commerce and Automobile to even Presidential Elections, predictions serve a great purpose. Most of these predictions are based on the data available about a person’s activity either online or in person.

# %% [markdown]
# ## Recommendation Engines are the much needed manifestations of the desired Predictability of User Activity. Recommendation Engines move one step further and not only give information but put forth strategies to further increase users interaction with the platform.

# %% [markdown]
# ## In today’s world OTT platform and Streaming Services have taken up a big chunk in the Retail and Entertainment industry. Organizations like Netflix, Amazon etc. analyse User Activity Pattern’s and suggest products that better suit the user needs and choices.

# %% [markdown]
# ## For the purpose of this Project we will be creating one such Recommendation Engine from the ground up, where every single user, based on there area of interest and ratings, would be recommended a list of movies that are best suited for them.

# %% [markdown]
# # Dataset Information

# %% [markdown]
# ## 1. ID -  Contains the separate keys for customer and movies.
# ## 2. Rating - A section contains the user ratings - for all the movies.
# ## 3. Genre -  Highlights the category of the movie.
# ## 4. Movie Name -  Name of the movie with respect to the movie id.

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importing the CombinedNetflixData  dataset

# %%
netflix_data=pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/combinedNetflixData.txt',header=None,names=['Cust_id','Rating'],usecols=[0,1])
netflix_data
# Out:
#           Cust_id  Rating
# 0              1:     NaN
# 1         1488844     3.0
# 2          822109     5.0
# 3          885013     4.0
# 4           30878     4.0
# ...           ...     ...
# 24058258  2591364     2.0
# 24058259  1791000     2.0
# 24058260   512536     5.0
# 24058261   988963     3.0
# 24058262  1704416     3.0
#
# [24058263 rows x 2 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1: is one movie , like we have 2: and soon

# %%
netflix_data[netflix_data['Cust_id']=='2:']
# Out:
#     Cust_id  Rating
# 548      2:     NaN

# %%
netflix_data.iloc[0:548]
# Out:
#      Cust_id  Rating
# 0         1:     NaN
# 1    1488844     3.0
# 2     822109     5.0
# 3     885013     4.0
# 4      30878     4.0
# ..       ...     ...
# 543  1790158     4.0
# 544  1403184     3.0
# 545  1535440     4.0
# 546  1426604     4.0
# 547  1815755     5.0
#
# [548 rows x 2 columns]

# %%
 netflix_data.isnull().sum()
# Out:
# Cust_id       0
# Rating     4499
# dtype: int64

# %% [markdown]
# ## How many movies are there in the dataset

# %%
movie_count = netflix_data.isnull().sum().iloc[1]
movie_count
# Out:
# 4499

# %%
netflix_data[netflix_data['Rating'].isnull()]
# Out:
#          Cust_id  Rating
# 0             1:     NaN
# 548           2:     NaN
# 694           3:     NaN
# 2707          4:     NaN
# 2850          5:     NaN
# ...          ...     ...
# 24046714   4495:     NaN
# 24047329   4496:     NaN
# 24056849   4497:     NaN
# 24057564   4498:     NaN
# 24057834   4499:     NaN
#
# [4499 rows x 2 columns]

# %%
Total_uniques = netflix_data['Cust_id'].nunique()
Total_uniques
# Out:
# 475257

# %%
customer_count_unique = Total_uniques - movie_count
customer_count_unique
# Out:
# 470758

# %% [markdown]
# ##  count of each ratings

# %%
netflix_data['Rating'].value_counts()
# Out:
# Rating
# 4.0    8085741
# 3.0    6904181
# 5.0    5506583
# 2.0    2439073
# 1.0    1118186
# Name: count, dtype: int64

# %%
netflix_data
# Out:
#           Cust_id  Rating
# 0              1:     NaN
# 1         1488844     3.0
# 2          822109     5.0
# 3          885013     4.0
# 4           30878     4.0
# ...           ...     ...
# 24058258  2591364     2.0
# 24058259  1791000     2.0
# 24058260   512536     5.0
# 24058261   988963     3.0
# 24058262  1704416     3.0
#
# [24058263 rows x 2 columns]

# %%
current_movie_id=None
movie_ids=[]
for id in netflix_data['Cust_id']:
  if ':' in id:
    current_movie_id=int(id.replace(':',''))
  movie_ids.append(current_movie_id)

netflix_data['movie ID']=movie_ids

# %%
netflix_data
# Out:
#           Cust_id  Rating  movie ID
# 0              1:     NaN         1
# 1         1488844     3.0         1
# 2          822109     5.0         1
# 3          885013     4.0         1
# 4           30878     4.0         1
# ...           ...     ...       ...
# 24058258  2591364     2.0      4499
# 24058259  1791000     2.0      4499
# 24058260   512536     5.0      4499
# 24058261   988963     3.0      4499
# 24058262  1704416     3.0      4499
#
# [24058263 rows x 3 columns]

# %%
netflix_data.dropna(inplace=True)

# %%
netflix_data=netflix_data.reset_index().drop('index',axis=1)
netflix_data
# Out:
#           Cust_id  Rating  movie ID
# 0         1488844     3.0         1
# 1          822109     5.0         1
# 2          885013     4.0         1
# 3           30878     4.0         1
# 4          823519     3.0         1
# ...           ...     ...       ...
# 24053759  2591364     2.0      4499
# 24053760  1791000     2.0      4499
# 24053761   512536     5.0      4499
# 24053762   988963     3.0      4499
# 24053763  1704416     3.0      4499
#
# [24053764 rows x 3 columns]

# %% [markdown]
# ## For getting count and average of rating and grouping on movie ids

# %%
netflix_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24053764 entries, 0 to 24053763
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   Cust_id   object
#  1   Rating    float64
#  2   movie ID  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 550.5+ MB

# %%
f=['count','mean']
ratings_summary = netflix_data.groupby('movie ID')['Rating'].agg(f).reset_index().sort_values(by='count')
ratings_summary
# Out:
#       movie ID   count      mean
# 4361      4362      36  2.000000
# 4337      4338      39  2.948718
# 3655      3656      42  3.214286
# 914        915      43  2.837209
# 4293      4294      44  4.272727
# ...        ...     ...       ...
# 570        571  154832  3.962585
# 4431      4432  156183  3.755364
# 3859      3860  160454  3.434517
# 2151      2152  162597  3.425322
# 1904      1905  193941  4.153908
#
# [4499 rows x 3 columns]

# %% [markdown]
# ## The data with more than  70% of ratings given by customers

# %%
benchmark=ratings_summary['count'].quantile(0.7)
benchmark=round(benchmark)
benchmark
# Out:
# 1799

# %%
ratings_summary[ratings_summary['count']<benchmark]
# Out:
#       movie ID  count      mean
# 4361      4362     36  2.000000
# 4337      4338     39  2.948718
# 3655      3656     42  3.214286
# 914        915     43  2.837209
# 4293      4294     44  4.272727
# ...        ...    ...       ...
# 3997      3998   1790  3.974302
# 2058      2059   1795  3.757660
# 2092      2093   1795  2.803343
# 1104      1105   1796  3.073497
# 1940      1941   1798  4.164071
#
# [3149 rows x 3 columns]

# %%
ratings_summary[ratings_summary['count']>benchmark]
# Out:
#       movie ID   count      mean
# 2869      2870    1801  3.417546
# 930        931    1809  3.054174
# 2567      2568    1812  4.461921
# 1912      1913    1812  3.189294
# 1054      1055    1817  3.330215
# ...        ...     ...       ...
# 570        571  154832  3.962585
# 4431      4432  156183  3.755364
# 3859      3860  160454  3.434517
# 2151      2152  162597  3.425322
# 1904      1905  193941  4.153908
#
# [1348 rows x 3 columns]

# %% [markdown]
# ## Indexes of data with less than 70% of ratings given by customers

# %%
drop_list=ratings_summary[ratings_summary['count']<benchmark].index

drop_list
# Out:
# Index([4361, 4337, 3655,  914, 4293,  819, 2804, 3692, 4034, 1857,
#        ...
#        2276, 2949, 2523, 3808, 1154, 3997, 2058, 2092, 1104, 1940],
#       dtype='int64', length=3149)

# %%
final_df=netflix_data[~netflix_data['movie ID'].isin(drop_list)]
final_df
# Out:
#           Cust_id  Rating  movie ID
# 547       2059652     4.0         2
# 548       1666394     3.0         2
# 549       1759415     4.0         2
# 550       1959936     5.0         2
# 551        998862     4.0         2
# ...           ...     ...       ...
# 24053759  2591364     2.0      4499
# 24053760  1791000     2.0      4499
# 24053761   512536     5.0      4499
# 24053762   988963     3.0      4499
# 24053763  1704416     3.0      4499
#
# [7017289 rows x 3 columns]

# %% [markdown]
# # Importing movies dataset

# %%
title=pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/movies.csv')
title
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 87580   292731           The Monroy Affaire (2022)
# 87581   292737          Shelter in Solitude (2023)
# 87582   292753                         Orca (2023)
# 87583   292755              The Angry Breed (1968)
# 87584   292757           Race to the Summit (2023)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 87580                                        Drama
# 87581                                 Comedy|Drama
# 87582                                        Drama
# 87583                                        Drama
# 87584                 Action|Adventure|Documentary
#
# [87585 rows x 3 columns]

# %%
title=title.rename(columns={'movieId':'movie ID','title':'title','genres':'generes'})
title
# Out:
#        movie ID                               title  \
# 0             1                    Toy Story (1995)
# 1             2                      Jumanji (1995)
# 2             3             Grumpier Old Men (1995)
# 3             4            Waiting to Exhale (1995)
# 4             5  Father of the Bride Part II (1995)
# ...         ...                                 ...
# 87580    292731           The Monroy Affaire (2022)
# 87581    292737          Shelter in Solitude (2023)
# 87582    292753                         Orca (2023)
# 87583    292755              The Angry Breed (1968)
# 87584    292757           Race to the Summit (2023)
#
#                                            generes
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 87580                                        Drama
# 87581                                 Comedy|Drama
# 87582                                        Drama
# 87583                                        Drama
# 87584                 Action|Adventure|Documentary
#
# [87585 rows x 3 columns]

# %% [markdown]
# ## Title data without drop list

# %%
fnal_title=title[~title['movie ID'].isin(drop_list)]
fnal_title
# Out:
#        movie ID                         title                       generes
# 1             2                Jumanji (1995)    Adventure|Children|Fantasy
# 6             7                Sabrina (1995)                Comedy|Romance
# 14           15       Cutthroat Island (1995)      Action|Adventure|Romance
# 15           16                 Casino (1995)                   Crime|Drama
# 16           17  Sense and Sensibility (1995)                 Drama|Romance
# ...         ...                           ...                           ...
# 87580    292731     The Monroy Affaire (2022)                         Drama
# 87581    292737    Shelter in Solitude (2023)                  Comedy|Drama
# 87582    292753                   Orca (2023)                         Drama
# 87583    292755        The Angry Breed (1968)                         Drama
# 87584    292757     Race to the Summit (2023)  Action|Adventure|Documentary
#
# [84512 rows x 3 columns]

# %% [markdown]
# # OBJECTIVE

# %% [markdown]
# #  1.Find out the list of most popular and liked genre

# %%
merge_data = pd.merge(final_df, fnal_title, on='movie ID')
merge_data
# Out:
#          Cust_id  Rating  movie ID                           title  \
# 0        2059652     4.0         2                  Jumanji (1995)
# 1        1666394     3.0         2                  Jumanji (1995)
# 2        1759415     4.0         2                  Jumanji (1995)
# 3        1959936     5.0         2                  Jumanji (1995)
# 4         998862     4.0         2                  Jumanji (1995)
# ...          ...     ...       ...                             ...
# 6954214  2591364     2.0      4499  Dirty Rotten Scoundrels (1988)
# 6954215  1791000     2.0      4499  Dirty Rotten Scoundrels (1988)
# 6954216   512536     5.0      4499  Dirty Rotten Scoundrels (1988)
# 6954217   988963     3.0      4499  Dirty Rotten Scoundrels (1988)
# 6954218  1704416     3.0      4499  Dirty Rotten Scoundrels (1988)
#
#                             generes
# 0        Adventure|Children|Fantasy
# 1        Adventure|Children|Fantasy
# 2        Adventure|Children|Fantasy
# 3        Adventure|Children|Fantasy
# 4        Adventure|Children|Fantasy
# ...                             ...
# 6954214                      Comedy
# 6954215                      Comedy
# 6954216                      Comedy
# 6954217                      Comedy
# 6954218                      Comedy
#
# [6954219 rows x 5 columns]

# %%
# Calculate average rating for each genre
genre_ratings = merge_data.groupby('generes')['Rating'].mean().sort_values(ascending=False)
print("\nTop-Rated Genres (by average rating):\n", genre_ratings)
# Out:
# Top-Rated Genres (by average rating):
#  generes
# Animation|Children|Comedy|Musical             4.581296
# Drama|Fantasy|Horror|Thriller                 4.408013
# Crime|Drama|Mystery|Romance|Thriller          4.338748
# Crime|Drama|Mystery|Thriller                  4.191729
# Animation|Comedy|Musical                      4.138889
#                                                 ...
# Horror|Western                                2.366888
# Adventure|Animation|Children|Drama|Musical    2.278689
# Adventure|Children|Comedy|Drama               2.086957
# Action|Drama|Romance|War                      1.954545
# Children|Musical                              1.933842
# Name: Rating, Length: 258, dtype: float64

# %% [markdown]
# ## Animation|Children|Comedy|Musical,
# ## Drama|Fantasy|Horror|Thriller,
# ## Crime|Drama|Mystery|Romance|Thriller,
# ## Crime|Drama|Mystery|Thriller,
# ## Animation|Comedy|Musical  are the top 5 rated genres(most popukar and liked genres)

# %% [markdown]
# #  2. Create Model that finds the best suited Movie for one user in every genre.

# %% [markdown]
# ## Recommendation System for Netflix Prize Dataset using SVD

# %% [markdown]
# # Importing the libraries

# %%
# !pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Downloading scikit_surprise-1.1.4.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 4.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (1.15.2)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (pyproject.toml) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp311-cp311-linux_x86_64.whl size=2505223 sha256=fc91e00d503d7ebd025172dc07f88e2b907cc1a6bf72312618f8fde2054e9ba6
#   Stored in directory: /root/.cache/pip/wheels/2a/8f/6e/7e2899163e2d85d8266daab4aa1cdabec7a6c56f83c015b5af
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.4

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.0.2'

# %%
pip install numpy==1.26.4
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.5 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 72.7 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
import math
import seaborn as sns
import numpy as np

from surprise import Reader,Dataset,SVD
from surprise.model_selection import cross_validate

# %%
reader =  Reader()

# %%
data =Dataset.load_from_df(final_df[['Cust_id','Rating','movie ID']][:100000],reader)

# %%
data

# %%
svd = SVD()

# %%
cross_validate(svd,data,measures=['RMSE','MAE'],verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    77.7104 77.4896 77.8403 77.7367 78.0935 77.7741 0.1964
# MAE (testset)     67.2547 67.3024 67.6500 67.5307 67.7869 67.5049 0.2024
# Fit time          1.88    1.92    1.77    2.17    2.89    2.13    0.41
# Test time         0.14    0.12    0.11    0.19    0.13    0.14    0.03
# {'test_rmse': array([77.71036353, 77.48958478, 77.84033048, 77.73666413, 78.09352406]),
#  'test_mae': array([67.2547 , 67.30245, 67.64995, 67.53075, 67.7869 ]),
#  'fit_time': (1.8787424564361572,
#   1.9215266704559326,
#   1.7663264274597168,
#   2.1671903133392334,
#   2.8923227787017822),
#  'test_time': (0.14360356330871582,
#   0.1247856616973877,
#   0.1064767837524414,
#   0.1854708194732666,
#   0.13048362731933594)}

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7017289 entries, 547 to 24053763
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   Cust_id   object
#  1   Rating    float64
#  2   movie ID  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 214.2+ MB

# %%
final_df['Cust_id'] = final_df['Cust_id'].astype('int')

# %%
final_df
# Out:
#           Cust_id  Rating  movie ID
# 547       2059652     4.0         2
# 548       1666394     3.0         2
# 549       1759415     4.0         2
# 550       1959936     5.0         2
# 551        998862     4.0         2
# ...           ...     ...       ...
# 24053759  2591364     2.0      4499
# 24053760  1791000     2.0      4499
# 24053761   512536     5.0      4499
# 24053762   988963     3.0      4499
# 24053763  1704416     3.0      4499
#
# [7017289 rows x 3 columns]

# %%
fnal_title
# Out:
#        movie ID                         title                       generes
# 1             2                Jumanji (1995)    Adventure|Children|Fantasy
# 6             7                Sabrina (1995)                Comedy|Romance
# 14           15       Cutthroat Island (1995)      Action|Adventure|Romance
# 15           16                 Casino (1995)                   Crime|Drama
# 16           17  Sense and Sensibility (1995)                 Drama|Romance
# ...         ...                           ...                           ...
# 87580    292731     The Monroy Affaire (2022)                         Drama
# 87581    292737    Shelter in Solitude (2023)                  Comedy|Drama
# 87582    292753                   Orca (2023)                         Drama
# 87583    292755        The Angry Breed (1968)                         Drama
# 87584    292757     Race to the Summit (2023)  Action|Adventure|Documentary
#
# [84512 rows x 3 columns]

# %%
np.random.choice(final_df['Cust_id'])
# Out:
# 1162377

# %% [markdown]
# ## Estimating the rating score for user id 1162377

# %%
user_1162377=final_df[(final_df['Cust_id']==1162377)&(final_df['Rating']==5)]
user_1162377
# Out:
#           Cust_id  Rating  movie ID
# 7337607   1162377     5.0      1470
# 10167523  1162377     5.0      1974
# 10678630  1162377     5.0      2102
# 11336721  1162377     5.0      2172
# 16208922  1162377     5.0      3150

# %%
fnal_title[fnal_title['movie ID']==1470]
# Out:
#       movie ID                  title      generes
# 1427      1470  Rhyme & Reason (1997)  Documentary

# %%
fnal_title[fnal_title['movie ID']==1974]
# Out:
#       movie ID                   title                  generes
# 1885      1974  Friday the 13th (1980)  Horror|Mystery|Thriller

# %%
user_1162377_merge =pd.merge(user_1162377,title,on='movie ID')
user_1162377_merge[['movie ID','title','generes']]
# Out:
#    movie ID                                              title  \
# 0      1470                              Rhyme & Reason (1997)
# 1      1974                             Friday the 13th (1980)
# 2      2102                            Steamboat Willie (1928)
# 3      2172  Strike! (a.k.a. All I Wanna Do, The Hairy Bird...
# 4      3150                               War Zone, The (1999)
#
#                              generes
# 0                        Documentary
# 1            Horror|Mystery|Thriller
# 2  Animation|Children|Comedy|Musical
# 3                       Comedy|Drama
# 4                     Drama|Thriller

# %%
user_1162377_merge
# Out:
#    Cust_id  Rating  movie ID  \
# 0  1162377     5.0      1470
# 1  1162377     5.0      1974
# 2  1162377     5.0      2102
# 3  1162377     5.0      2172
# 4  1162377     5.0      3150
#
#                                                title  \
# 0                              Rhyme & Reason (1997)
# 1                             Friday the 13th (1980)
# 2                            Steamboat Willie (1928)
# 3  Strike! (a.k.a. All I Wanna Do, The Hairy Bird...
# 4                               War Zone, The (1999)
#
#                              generes
# 0                        Documentary
# 1            Horror|Mystery|Thriller
# 2  Animation|Children|Comedy|Musical
# 3                       Comedy|Drama
# 4                     Drama|Thriller

# %%
user_1162377_merge=user_1162377_merge[~user_1162377_merge['movie ID'].isin(drop_list)]
user_1162377_merge
# Out:
#    Cust_id  Rating  movie ID  \
# 0  1162377     5.0      1470
# 1  1162377     5.0      1974
# 2  1162377     5.0      2102
# 3  1162377     5.0      2172
# 4  1162377     5.0      3150
#
#                                                title  \
# 0                              Rhyme & Reason (1997)
# 1                             Friday the 13th (1980)
# 2                            Steamboat Willie (1928)
# 3  Strike! (a.k.a. All I Wanna Do, The Hairy Bird...
# 4                               War Zone, The (1999)
#
#                              generes
# 0                        Documentary
# 1            Horror|Mystery|Thriller
# 2  Animation|Children|Comedy|Musical
# 3                       Comedy|Drama
# 4                     Drama|Thriller

# %% [markdown]
# ## Prediction of rating for user

# %%
user_1162377_merge['rating_estimation_score']=user_1162377_merge['movie ID'].apply(lambda x:svd.predict(1162377,x).est)

# %%
user_1162377_merge.sort_values('rating_estimation_score')
user_1162377_merge
# Out:
#    Cust_id  Rating  movie ID  \
# 0  1162377     5.0      1470
# 1  1162377     5.0      1974
# 2  1162377     5.0      2102
# 3  1162377     5.0      2172
# 4  1162377     5.0      3150
#
#                                                title  \
# 0                              Rhyme & Reason (1997)
# 1                             Friday the 13th (1980)
# 2                            Steamboat Willie (1928)
# 3  Strike! (a.k.a. All I Wanna Do, The Hairy Bird...
# 4                               War Zone, The (1999)
#
#                              generes  estimation score  \
# 0                        Documentary                 5
# 1            Horror|Mystery|Thriller                 5
# 2  Animation|Children|Comedy|Musical                 5
# 3                       Comedy|Drama                 5
# 4                     Drama|Thriller                 5
#
#    rating_estimation_score
# 0                        5
# 1                        5
# 2                        5
# 3                        5
# 4                        5

# %% [markdown]
# ## 3.  Find what Genre Movies have received the best and worst ratings based on User Rating

# %%
user1162377=final_df[final_df['Cust_id']==1162377]
user1162377
# Out:
#           Cust_id  Rating  movie ID
# 670259    1162377     3.0       179
# 1012305   1162377     4.0       239
# 1918176   1162377     3.0       357
# 1985280   1162377     4.0       359
# 1997800   1162377     2.0       361
# 2255043   1162377     3.0       426
# 2293739   1162377     4.0       442
# 3333492   1162377     4.0       620
# 3912380   1162377     3.0       758
# 4016370   1162377     4.0       760
# 4871740   1162377     4.0       985
# 5043419   1162377     4.0      1020
# 5145321   1162377     3.0      1046
# 6227443   1162377     3.0      1220
# 7337607   1162377     5.0      1470
# 8557773   1162377     4.0      1707
# 8568312   1162377     4.0      1708
# 9459295   1162377     1.0      1865
# 10167523  1162377     5.0      1974
# 10678630  1162377     5.0      2102
# 10721102  1162377     4.0      2112
# 11305080  1162377     4.0      2171
# 11336721  1162377     5.0      2172
# 12360651  1162377     2.0      2378
# 12898450  1162377     4.0      2456
# 14322638  1162377     3.0      2779
# 14384893  1162377     4.0      2782
# 16208922  1162377     5.0      3150
# 17526237  1162377     3.0      3368
# 20007527  1162377     3.0      3825
# 20491079  1162377     3.0      3893
# 20789739  1162377     3.0      3925
# 21419476  1162377     4.0      4011
# 22498730  1162377     3.0      4266
# 23070955  1162377     4.0      4345
# 23155631  1162377     4.0      4353

# %%
user1162377_merge =pd.merge(user1162377,title,on='movie ID')
user1162377_merge
# Out:
#     Cust_id  Rating  movie ID  \
# 0   1162377     3.0       179
# 1   1162377     4.0       239
# 2   1162377     3.0       357
# 3   1162377     4.0       359
# 4   1162377     2.0       361
# 5   1162377     3.0       426
# 6   1162377     4.0       442
# 7   1162377     4.0       620
# 8   1162377     3.0       758
# 9   1162377     4.0       760
# 10  1162377     4.0       985
# 11  1162377     4.0      1020
# 12  1162377     3.0      1046
# 13  1162377     3.0      1220
# 14  1162377     5.0      1470
# 15  1162377     4.0      1707
# 16  1162377     4.0      1708
# 17  1162377     1.0      1865
# 18  1162377     5.0      1974
# 19  1162377     5.0      2102
# 20  1162377     4.0      2112
# 21  1162377     4.0      2171
# 22  1162377     5.0      2172
# 23  1162377     2.0      2378
# 24  1162377     4.0      2456
# 25  1162377     3.0      2779
# 26  1162377     4.0      2782
# 27  1162377     5.0      3150
# 28  1162377     3.0      3368
# 29  1162377     3.0      3825
# 30  1162377     3.0      3893
# 31  1162377     3.0      3925
# 32  1162377     4.0      4011
# 33  1162377     3.0      4266
# 34  1162377     4.0      4345
# 35  1162377     4.0      4353
#
#                                                 title  \
# 0                                     Mad Love (1995)
# 1                               Goofy Movie, A (1995)
# 2                  Four Weddings and a Funeral (1994)
# 3                          I Like It Like That (1994)
# 4                       It Could Happen to You (1994)
# 5                               Body Snatchers (1993)
# 6                               Demolition Man (1993)
# 7   Scream of Stone (Cerro Torre: Schrei aus Stein...
# 8                           Jar, The (Khomreh) (1992)
# 9                                   Stalingrad (1993)
# 10                               Small Wonders (1995)
# 11                               Cool Runnings (1993)
# 12                             Beautiful Thing (1996)
# 13                         Blues Brothers, The (1980)
# 14                              Rhyme & Reason (1997)
# 15                                Home Alone 3 (1997)
# 16                            Ill Gotten Gains (1997)
# 17                              Wild Man Blues (1997)
# 18                             Friday the 13th (1980)
# 19                            Steamboat Willie (1928)
# 20                                Grand Canyon (1991)
# 21                        Next Stop Wonderland (1998)
# 22  Strike! (a.k.a. All I Wanna Do, The Hairy Bird...
# 23                              Police Academy (1984)
# 24                                 Fly II, The (1989)
# 25                             Heaven Can Wait (1978)
# 26                        Pit and the Pendulum (1961)
# 27                               War Zone, The (1999)
# 28                            Big Country, The (1958)
# 29                                 Coyote Ugly (2000)
# 30                                 Nurse Betty (2000)
# 31                      Stranger Than Paradise (1984)
# 32                                      Snatch (2000)
# 33                               Forsaken, The (2001)
# 34                      Anniversary Party, The (2001)
# 35                              Uncommon Valor (1983)
#
#                                 generes
# 0                         Drama|Romance
# 1     Animation|Children|Comedy|Romance
# 2                        Comedy|Romance
# 3                  Comedy|Drama|Romance
# 4                  Comedy|Drama|Romance
# 5                Horror|Sci-Fi|Thriller
# 6               Action|Adventure|Sci-Fi
# 7                                 Drama
# 8                                 Drama
# 9                             Drama|War
# 10                          Documentary
# 11                               Comedy
# 12                        Drama|Romance
# 13                Action|Comedy|Musical
# 14                          Documentary
# 15                      Children|Comedy
# 16                                Drama
# 17                          Documentary
# 18              Horror|Mystery|Thriller
# 19    Animation|Children|Comedy|Musical
# 20                          Crime|Drama
# 21                 Comedy|Drama|Romance
# 22                         Comedy|Drama
# 23                         Comedy|Crime
# 24                        Horror|Sci-Fi
# 25                               Comedy
# 26                               Horror
# 27                       Drama|Thriller
# 28                      Romance|Western
# 29                 Comedy|Drama|Romance
# 30  Comedy|Crime|Drama|Romance|Thriller
# 31                         Comedy|Drama
# 32                Comedy|Crime|Thriller
# 33                               Horror
# 34                                Drama
# 35                           Action|War

# %%
user1162377_merge=user1162377_merge[~user1162377_merge['movie ID'].isin(drop_list)]
user1162377_merge.head()
# Out:
#    Cust_id  Rating  movie ID                               title  \
# 0  1162377     3.0       179                     Mad Love (1995)
# 1  1162377     4.0       239               Goofy Movie, A (1995)
# 2  1162377     3.0       357  Four Weddings and a Funeral (1994)
# 3  1162377     4.0       359          I Like It Like That (1994)
# 4  1162377     2.0       361       It Could Happen to You (1994)
#
#                              generes
# 0                      Drama|Romance
# 1  Animation|Children|Comedy|Romance
# 2                     Comedy|Romance
# 3               Comedy|Drama|Romance
# 4               Comedy|Drama|Romance

# %%
genre_ratings = user1162377_merge.groupby('generes')['Rating'].mean()
genre_ratings
# Out:
# generes
# Action|Adventure|Sci-Fi                4.000000
# Action|Comedy|Musical                  3.000000
# Action|War                             4.000000
# Animation|Children|Comedy|Musical      5.000000
# Animation|Children|Comedy|Romance      4.000000
# Children|Comedy                        4.000000
# Comedy                                 3.500000
# Comedy|Crime                           2.000000
# Comedy|Crime|Drama|Romance|Thriller    3.000000
# Comedy|Crime|Thriller                  4.000000
# Comedy|Drama                           4.000000
# Comedy|Drama|Romance                   3.250000
# Comedy|Romance                         3.000000
# Crime|Drama                            4.000000
# Documentary                            3.333333
# Drama                                  3.750000
# Drama|Romance                          3.000000
# Drama|Thriller                         5.000000
# Drama|War                              4.000000
# Horror                                 3.500000
# Horror|Mystery|Thriller                5.000000
# Horror|Sci-Fi                          4.000000
# Horror|Sci-Fi|Thriller                 3.000000
# Romance|Western                        3.000000
# Name: Rating, dtype: float64

# %%
best_genre = genre_ratings.idxmax()
worst_genre = genre_ratings.idxmin()
best_rating = genre_ratings.max()
worst_rating = genre_ratings.min()

# %%
print(f"Best Genre: {best_genre} (Average Rating: {best_rating:.2f})")
print(f"Worst Genre: {worst_genre} (Average Rating: {worst_rating:.2f})")
# Out:
# Best Genre: Animation|Children|Comedy|Musical (Average Rating: 5.00)
# Worst Genre: Comedy|Crime (Average Rating: 2.00)

# %% [markdown]
#  ## Animation|Children|Comedy|Musical is the best genre  and Comedy|Crime is the worst genre
